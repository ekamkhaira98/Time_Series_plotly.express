# %% [markdown]
# # Enhancing Time-Series Data Visualizations using plotly.express

# %% [markdown]
# Let us learn how to add buttons and range selector in our Temporal Data Visualizations using Python library- plotly
#
# **Step 1- Install plotly**

# %%
# !pip3 install plotly
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (5.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly) (23.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip3 install --upgrade pip

# %% [markdown]
# **Step 2- Import Pandas for CSV file Data Input, plotly.express and matplotlib for visualization aspect**

# %%
import pandas as pd
import plotly.express as px
import matplotlib as mpl

# %% [markdown]
# **Step 3- Set parameters for Graph Display**

# %%
mpl.rcParams['figure.figsize'] = (10, 8)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# **Step 4- Import Time-Series Dataset with atleast one Column with Count Value e.g in this case column: Total-Logins represents Total Logins of a User in an Hour period**

# %%
df = pd.read_csv('plotly_log_file.csv')

# %% [markdown]
# **Step 5- Extract data of a User or particular object which you want to view e.g I want to view total logins of User1 over a period of 3 Months**

# %%
user1_rows=df[df['Username'] == 'User1@company.com']
user1_rows = user1_rows.reset_index()

# %% [markdown]
# **Step 6- Two Columns are being utilized by plotly. One column contains Datetime values, other one has Count values**
#
# - Set rangeslider_visible parameter as True to view a Date Range Slider in the viz
# - Set rangeselector parameter as a dictionary of buttons. Here we are adding 3 buttons with month-wise backward step.
# - Customise the values as per your requirements

# %%
buttons=list([
              dict(count=1, label='This Month', step="month", stepmode="backward"),
              dict(count=2, label='Last 2 months', step="month", stepmode="backward"),
              dict(count=3, label='All Time', step="month", stepmode="backward")
        ])

# %%
fig = px.line(user1_rows.reset_index(), x='Time', y='Total_Logins', title='Total Logins for User: User1')
fig.update_xaxes(
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = buttons
    )
)
fig.show()
# Out:
# <div>                            <div id="9541f0fb-7f56-4bc5-9bab-2835a4c612d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9541f0fb-7f56-4bc5-9bab-2835a4c612d9")) {                    Plotly.newPlot(                        "9541f0fb-7f56-4bc5-9bab-2835a4c612d9",                        [{"hovertemplate":"Time=%{x}\u003cbr\u003eTotal_Logins=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2023-06-01 00:00:00","2023-06-01 00:00:00","2023-06-01 01:00:00","2023-06-01 01:00:00","2023-06-01 02:00:00","2023-06-01 03:00:00","2023-06-01 04:00:00","2023-06-01 04:00:00","2023-06-01 05:00:00","2023-06-01 05:00:00","2023-06-01 06:00:00","2023-06-01 06:00:00","2023-06-01 07:00:00","2023-06-01 07:00:00","2023-06-01 08:00:00","2023-06-01 08:00:00","2023-06-01 09:00:00","2023-06-01 09:00:00","2023-06-01 10:00:00","2023-06-01 10:00:00","2023-06-01 11:00:00","2023-06-01 11:00:00","2023-06-01 12:00:00","2023-06-01 13:00:00","2023-06-01 14:00:00","2023-06-01 14:00:00","2023-06-01 15:00:00","2023-06-01 16:00:00","2023-06-01 16:00:00","2023-06-01 17:00:00","2023-06-01 18:00:00","2023-06-01 18:00:00","2023-06-01 19:00:00","2023-06-01 19:00